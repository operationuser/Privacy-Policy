# %% [markdown]
# # Test server URL
# mongodb://stage:stage@ds021809-shard-00-02.g1rhi.mongodb.net:27017/boricha-stage?authSource=admin&tls=true"

# %%
from pymongo import MongoClient
from pprint import pprint #이쁘게 프린트할 수 있도록 도와줌
import json

# %%
testURL = 'mongodb://stage:stage@ds021809-shard-00-02.g1rhi.mongodb.net:27017/boricha-stage?authSource=admin&tls=true'
client = MongoClient(testURL)
print(client)
# Out:
# MongoClient(host=['ds021809-shard-00-02.g1rhi.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', ssl=True)

# %%
db = client['boricha-stage']
print(db)
# Out:
# Database(MongoClient(host=['ds021809-shard-00-02.g1rhi.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', ssl=True), 'boricha-stage')

# %%
cur = db.Reservation.find({"bookedDate":"20200629"}).limit(1)

# %%
for c in cur:
    pprint(c)
# Out:
# {'_created_at': datetime.datetime(2020, 6, 1, 15, 21, 1, 850000),
#  '_id': 'EbXeC8WLa9',
#  '_p_consumer': 'Consumer$fnzD0rjFeC',
#  '_p_creditCard': 'CreditCard$nRMsQiFfJS',
#  '_updated_at': datetime.datetime(2020, 6, 29, 3, 48, 1, 975000),
#  'billingCost': 27000,
#  'bookedDate': '20200629',
#  'details': {'hours': [1500, 1530, 1600, 1630], 'isRepeat': True},
#  'isImported': True,
#  'providerId': 'USYT5mA5vm',
#  'providerIncome': 24000,
#  'requestId': 'LGtaDsMOiB',
#  'sentPushTimeToPrepareState': {'USYT5mA5vm': '202006291500'},
#  'serviceCode': 'HCW',
#  'serviceCost': 27000}

# %% [markdown]
# # 컬랙션 이름 찾는 코드

# %%
for coll in db.list_collection_names():
    print(coll)
# Out:
# HouseCleanCleanerInfo
# CouponHistory
# MoveCleanRequest
# ProviderApplicant
# ChatRoom
# ProviderEducatee
# _Audience
# AddressBook
# HouseCleanCleaner
# HouseCleanCleanerReview
# Service
# _JobStatus
# AreaCategory
# ConsumerProfile
# MoveCleanProviderWanted
# objectlabs-system
# CreditCard
# _Installation
# MetroStation
# Coupon
# HouseCleanCleanerPaymentHistory
# PhoneAuthentication
# Item
# Payment
# WebSocketClient
# Option
# MoveCleanProviderInfo
# DayBaseProviderSchedule
# ProviderInvitation
# AppleJuice.Customer
# Event
# HouseCleanRequest
# _GlobalConfig
# Area
# ProviderBonus
# MoveCleanProviderSchedule
# HouseCleanCleanerWanted
# CreditHistory
# ReservationMemo
# Operator
# WhiteApplianceRequest
# _Role
# HouseCleanCleanerProfile
# HouseCleanCleanerSchedule
# InstallationDailyHitCount
# MoveCleanProviderReview
# AreaLink
# _SCHEMA
# Category
# AppleJuice.Housekeeper
# HouseCleanCleanerRepeatSchedule
# PaymentFail
# InstantPayment
# HouseCleanRequestWeekly
# ...

# %%
scheme = db["_User"].aggregate([
    {"$project":{"o":{"$objectToArray":"$$ROOT"}}},
    {"$unwind":"$o"},
    {"$group":{"_id":None, "keys":{"$addToSet":"$o.k"}}}
])

# %%
for s in scheme:
    pprint(s)
# Out:
# {'_id': None,
#  'keys': ['memo',
#           'password',
#           '_p_timeBaseProvider',
#           '_p_houseCleanCleaner',
#           '_p_moveCleanProvider',
#           '_acl',
#           '_p_dayBaseProvider',
#           '_wperm',
#           '_hashed_password',
#           '_updated_at',
#           'phone',
#           '_created_at',
#           'isPhoneVerified',
#           '_id',
#           'username',
#           '_p_operator',
#           '_p_consumer',
#           'email',
#           'withdrawn',
#           '_rperm',
#           'userFullName']}

# %% [markdown]
# # operator	설명
#
# $eq	(equals) : 주어진 값과 일치하는 값
#
# $gt	(greater than) 주어진 값보다 큰 값
#
# $gte	(greather than or equals) 주어진 값보다 크거나 같은 값
#
# $lt	(less than) 주어진 값보다 작은 값
#
# $lte	(less than or equals) 주어진 값보다 작거나 같은 값
#
# $ne	(not equal) 주어진 값과 일치하지 않는 값
#
# $in	주어진 배열 안에 속하는 값
#
# $nin	주어빈 배열 안에 속하지 않는

# %%
cur = db.Consumer.find()

# %%
# Out:
# {'_created_at': datetime.datetime(2016, 9, 30, 11, 3, 41, 471000),
#  '_id': 'hZorQpWpFz',
#  '_p_consumer': '_User$yDXlefQkOl',
#  '_updated_at': datetime.datetime(2016, 10, 21, 3, 58, 48, 38000)}
# {'_created_at': datetime.datetime(2016, 4, 13, 6, 18, 14, 74000),
#  '_id': 'BWSqfXMq4G',
#  '_p_consumer': '_User$npoR9LLPNT',
#  '_updated_at': datetime.datetime(2020, 5, 28, 5, 59, 40, 736000),
#  'serviceArea': ''}
# {'_created_at': datetime.datetime(2016, 10, 19, 9, 19, 9, 745000),
#  '_id': 'E0ut8xa3yX',
#  '_p_consumer': '_User$Le27qmv1jB',
#  '_updated_at': datetime.datetime(2016, 10, 21, 3, 58, 30, 123000)}
# {'_created_at': datetime.datetime(2017, 11, 28, 2, 8, 33, 329000),
#  '_id': 'k8pAbqEI56',
#  '_p_consumer': '_User$Zg6C64Oyfv',
#  '_updated_at': datetime.datetime(2017, 11, 28, 2, 8, 33, 329000)}
# {'_created_at': datetime.datetime(2016, 2, 3, 7, 28, 49, 311000),
#  '_id': 'SdQQsYIY5M',
#  '_p_consumer': '_User$5LRC6PSywK',
# ...
